# %%
from utility import data_preparation, BM25_retrieval, dense_retrieval, metrics_calculation, plot_top_k_metrics_vs_k_prime

# %% [markdown]
# Dataset name

# %%
dataset="scidocs"

# %% [markdown]
# Data Preparation

# %%
documents, queries = data_preparation(dataset)

# %%
documents

# %%
queries

# %% [markdown]
# Sparse Vector Score

# %%
results_sparse = BM25_retrieval(documents, queries)

# %%
results_sparse

# %% [markdown]
# Dense Vector Score

# %%
results_dense = dense_retrieval(documents, queries)

# %%
results_dense

# %% [markdown]
# Metrics calculation and plot

# %%
metrics_per_k=metrics_calculation(dataset, results_sparse,results_dense)

# %%
plot_top_k_metrics_vs_k_prime(metrics_per_k)
